# %%
import gymnasium as gym
import numpy as np
import random

# %%
# epsilon-policy
def epsilon_greedy(state):
    if random.random() < epsilon:
        return env.action_space.sample() # explore
    else:
        return np.argmax(Q[state])

# %%
Q = np.zeros((48,4))

# %%
gamma = 0.99
epsilon = 0.1
alpha = 0.5
episodes = 500

# %%
# Q Learning algorithm

for episode in range(episodes):

    render = (episode % 100 == 0)

    if render:
        env = gym.make("CliffWalking-v1", render_mode = "human")
    else :
        env = gym.make("CliffWalking-v1")

    done = False
    state, _ = env.reset()

    episode_len = 0
    tot_reward = 0

    while not done:
        action = epsilon_greedy(state)

        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated 

        # Q-Learning update (Q table update)
        Q[state, action] += alpha * (reward + gamma * np.max(Q[next_state]) - Q[state, action])

        state = next_state

        episode_len += 1
        tot_reward += reward

    print(f"EPISODE = {episode + 1}/500 & total_reward = {tot_reward} & episode_len = {episode_len}")
    env.close()
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# EPISODE = 1/500 & total_reward = -76 & episode_len = 76
# EPISODE = 2/500 & total_reward = -1890 & episode_len = 603
# EPISODE = 3/500 & total_reward = -108 & episode_len = 108
# EPISODE = 4/500 & total_reward = -79 & episode_len = 79
# EPISODE = 5/500 & total_reward = -72 & episode_len = 72
# EPISODE = 6/500 & total_reward = -59 & episode_len = 59
# EPISODE = 7/500 & total_reward = -36 & episode_len = 36
# EPISODE = 8/500 & total_reward = -211 & episode_len = 112
# EPISODE = 9/500 & total_reward = -72 & episode_len = 72
# EPISODE = 10/500 & total_reward = -164 & episode_len = 65
# ...

# %% [markdown]
# ###  What did our agent Learn

# %%
env = gym.make("CliffWalking-v1", render_mode = "human")
state,_ = env.reset()
total_reward = 0
episode_len = 0
done = False

while not done:
    action = np.argmax(Q[state])
    state, reward, terminated, trucated, _ = env.step(action)
    done = terminated or truncated

    episode_len += 1
    total_reward += reward

print(f"total_reward = {total_reward} & episode len = {episode_len}")
env.close()
# Out:
# total_reward = -13 & episode len = 13

# %%
Q[36] # Q[S,A] state = 36
# Out:
# array([ -12.2478977 , -112.12516045,  -13.12540904,  -13.12537552])

# %%
Q[35] # Q[S,A] state = 35
# Out:
# array([-2.9698743 , -1.98951417, -1.        , -2.96407627])
